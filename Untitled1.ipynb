# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

pd_data=pd.read_excel(r'/Users/litrc/线性回归1.xlsx')
print('pd_data.head(10)=\n{}'.format(pd_data.head(10)))
sns.pairplot(pd_data, x_vars=['国内生产总之GDP','货币供应量M2'], y_vars='年份',kind="reg", size=5, aspect=0.7)
plt.show()
# Out:
# pd_data.head(10)=
#      年份   货币供应量M2  国内生产总之GDP
# 0  1990   15293.4    18718.3
# 1  1991   19349.9    21826.2
# 2  1992   25402.2    26937.3
# 3  1993   34879.8    35260.0
# 4  1994   46923.5    48108.5
# 5  1995   60750.5    59810.5
# 6  1996   76094.9    70142.5
# 7  1997   90995.3    78060.8
# 8  1998  104498.5    83024.3
# 9  1999  119897.9    88379.2
# /Users/litrc/opt/anaconda3/lib/python3.8/site-packages/seaborn/axisgrid.py:2071: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# /Users/litrc/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 22269 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/litrc/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 20869 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...
